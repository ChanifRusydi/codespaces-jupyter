# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: Muchammad 'Irfan Chanif Rusydi
# - Email: chanif.rusydi@gmail.com
# - Id Dicoding: Chanif Rusydi

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - pertanyaan 1
# - pertanyaan 2

# %% [markdown]
# ## Import library yang dibutuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day = pd.read_csv('../data/day.csv')

# %%
hour = pd.read_csv('../data/hour.csv')

# %%
day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %%
print(True if day['instant'].count() == hour['instant'].count()*24 else False)
# Out:
# False

# %%
day_count_times_24 = day['instant'].count()*24
day_count_times_24
# Out:
# 17544

# %%
hour_count = hour['instant'].count()
hour_count
# Out:
# 17379

# %%
day_count_times_24 - hour_count
# Out:
# 165

# %%
day.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
hour.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
day.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
each_hour_count = hour.groupby('hr').count()
each_hour_count
# Out:
#     instant  dteday  season   yr  mnth  holiday  weekday  workingday  \
# hr
# 0       726     726     726  726   726      726      726         726
# 1       724     724     724  724   724      724      724         724
# 2       715     715     715  715   715      715      715         715
# 3       697     697     697  697   697      697      697         697
# 4       697     697     697  697   697      697      697         697
# 5       717     717     717  717   717      717      717         717
# 6       725     725     725  725   725      725      725         725
# 7       727     727     727  727   727      727      727         727
# 8       727     727     727  727   727      727      727         727
# 9       727     727     727  727   727      727      727         727
# 10      727     727     727  727   727      727      727         727
# 11      727     727     727  727   727      727      727         727
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore and Analyze Data

# %%
# plot data correlation
import seaborn as sns
corr = hour.corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu')
# Out:
# /tmp/ipykernel_1651/2657845162.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = hour.corr()
# <Axes: >

# %%
hour = hour.drop(columns=['instant', 'yr'])

# %%
sns.heatmap(hour.corr(), annot=True, cmap='YlGnBu')
# Out:
# /tmp/ipykernel_1651/947071484.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(hour.corr(), annot=True, cmap='YlGnBu')
# <Axes: >

# %% [markdown]
# ### Convert to category

# %%
columns = [
    'season',
    "mnth",
    "holiday",
    "weekday",
    "workingday",
    "weathersit",
]
for column in columns:
    day[column] = day[column].astype('category')
    hour[column] = hour[column].astype('category')
day.info()
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    category
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    category
#  5   holiday     731 non-null    category
#  6   weekday     731 non-null    category
#  7   workingday  731 non-null    category
#  8   weathersit  731 non-null    category
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: category(6), float64(4), int64(5), object(1)
# memory usage: 62.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
figure, ax = plt.subplots(figsize=(10, 10))
sns.pointplot(data=hour, x='hr', y='cnt', hue='weekday', ax=ax)
ax.set(title='Bike Sharing Total Users by Hours for each Days in Weekdays', xlabel='Hours', ylabel='Users')
# Out:
# [Text(0.5, 1.0, 'Bike Sharing Total Users by Hours for each Days in Weekdays'),
#  Text(0.5, 0, 'Hours'),
#  Text(0, 0.5, 'Users')]

# %%
figure, ax = plt.subplots(figsize=(10, 10))
sns.barplot(data=hour, x='weekday', y='cnt')
ax.set(title='Bike Sharing Total Users by Days in Weekdays', xlabel='Days', ylabel='Users')
# Out:
# [Text(0.5, 1.0, 'Bike Sharing Total Users by Days in Weekdays'),
#  Text(0.5, 0, 'Days'),
#  Text(0, 0.5, 'Users')]

# %%
figure, ax = plt.subplots(figsize=(10, 10))
sns.regplot(data=hour, x='temp', y='cnt', ax=ax)
# Out:
# <Axes: xlabel='temp', ylabel='cnt'>

# %%
sns.regplot(data=hour, x='hum', y='cnt')
ax.set(title='Bike Sharing Total Users by Humidity', xlabel='Humidity', ylabel='Users')
# Out:
# [Text(0.5, 1.0, 'Bike Sharing Total Users by Humidity'),
#  Text(0.5, 24.0, 'Humidity'),
#  Text(24.0, 0.5, 'Users')]

# %%
figure, ax = plt.subplots(figsize=(10, 10))
sns.regplot(data=hour, x='windspeed', y='cnt', ax=ax)
# Out:
# <Axes: xlabel='windspeed', ylabel='cnt'>

# %%
X = data.drop(['cnt'], axis=1)
Y = data['cnt']

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - conclution pertanyaan 2
